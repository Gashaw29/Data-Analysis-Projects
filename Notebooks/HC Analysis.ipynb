# %%
# HEALTHCARE DATA ANALYSIS PROJECT

# %%
# Import Data Analysis Libraries

# %%
import os
import pandas as pd  # Data analysis
import numpy as np   # Calculations
import matplotlib.pyplot as plt   # Charts

# Display plots inside notebook

# %matplotlib inline

# %%
print("Current working directory:", os.getcwd())
print("\nFiles in current directory:")
print(os.listdir('.'))


if os.path.exists('Data'):
    print("\nFiles in 'data' directory:")
    print(os.listdir('Data'))
else:
    print("\n'data' directory does not exist")
# Out:
# Current working directory: C:\Users\gasha\HC_AI_Projects
#
# Files in current directory:
# ['.ipynb_checkpoints', 'App', 'Dashboard', 'Data', 'HC Analysis.ipynb', 'Model', 'Notebooks', 'Reports']
#
# Files in 'data' directory:
# ['Enhanced_Healthcare_AI_Dataset.csv', 'Healthcare Dataset.csv', 'Healthcare_AI_Project_Notebook.ipynb']

# %%
# Load Healthcare Dataset

# %%
df = pd.read_csv("Data/Enhanced_Healthcare_AI_Dataset.csv")

# Display first rows
df.head()
# Out:
#   Patient_ID           Name  Age  Gender Blood Type Medical Condition  \
# 0    P000001  Bobby JacksOn   30    Male         B-            Cancer
# 1    P000002   LesLie TErRy   62    Male         A+           Obesity
# 2    P000003    DaNnY sMitH   79  Female         A-           Obesity
# 3    P000004   andrEw waTtS   28  Female         O+          Diabetes
# 4    P000005  adrIENNE bEll   43  Female        AB+            Cancer
#
#   Date of Admission Discharge Date            Doctor  \
# 0         1/31/2024       2/2/2024     Matthew Smith
# 1         8/20/2019      8/26/2019   Samantha Davies
# 2         9/22/2022      10/7/2022  Tiffany Mitchell
# 3        11/18/2020     12/18/2020       Kevin Wells
# 4         9/19/2022      10/9/2022    Kathleen Hanna
#
#                      Hospital  ... Room Number Billing Amount   Medication  \
# 0             Sons and Miller  ...         328   18856.281306  Paracetamol
# ...

# %%
#Show dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55500 entries, 0 to 55499
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Patient_ID          55500 non-null  object
#  1   Name                55500 non-null  object
#  2   Age                 55500 non-null  int64
#  3   Gender              55500 non-null  object
#  4   Blood Type          55500 non-null  object
#  5   Medical Condition   55500 non-null  object
#  6   Date of Admission   55500 non-null  object
#  7   Discharge Date      55500 non-null  object
#  8   Doctor              55500 non-null  object
#  9   Hospital            55500 non-null  object
#  10  Insurance Provider  55500 non-null  object
#  11  Admission Type      55500 non-null  object
#  12  Room Number         55500 non-null  int64
#  13  Billing Amount      55500 non-null  float64
#  14  Medication          55500 non-null  object
# ...

# %%
# Standardizing columnj names
print("Original column names:")
print(df.columns.tolist())
# Out:
# Original column names:
# ['Patient_ID', 'Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition', 'Date of Admission', 'Discharge Date', 'Doctor', 'Hospital', 'Insurance Provider', 'Admission Type', 'Room Number', 'Billing Amount', 'Medication', 'Test Results', 'Heart_Rate', 'BMI', 'Length_of_Stay', 'Readmission_Risk', 'Outcome', 'Diabetes_Risk']

# %%
# check missing values
df.isnull().sum()
# Out:
# Patient_ID            0
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Discharge Date        0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Admission Type        0
# Room Number           0
# Billing Amount        0
# Medication            0
# Test Results          0
# Heart_Rate            0
# BMI                   0
# Length_of_Stay        0
# Readmission_Risk      0
# Outcome               0
# Diabetes_Risk         0
# dtype: int64

# %%
# Conver All rows in "Name" column to Sentence case

df['Name'] = df['Name'].str.strip().str.title()

# %%
#Export the cleaned file

df.to_csv("Reports/Cleaned_patients.csv", index=False)

# %%
# Statistical Summary
df.describe()
# Out:
#                 Age  Billing Amount   Room Number
# count  55500.000000    55500.000000  55500.000000
# mean      51.539514    25539.316097    301.134829
# std       19.602525    14211.454431    115.243069
# min       13.000000    -2008.492140    101.000000
# 25%       35.000000    13241.224652    202.000000
# 50%       52.000000    25538.069376    302.000000
# 75%       68.000000    37820.508436    401.000000
# max       89.000000    52764.276736    500.000000

# %%
#Count diseases

disease_count = df['Medical Condition'].value_counts()

print(disease_count)
# Out:
# Medical Condition
# Arthritis       9308
# Diabetes        9304
# Hypertension    9245
# Obesity         9231
# Cancer          9227
# Asthma          9185
# Name: count, dtype: int64

# %%
#Medication Count

Med_count = df['Medication'].value_counts()

print(Med_count)
# Out:
# Medication
# Lipitor        11140
# Ibuprofen      11127
# Aspirin        11094
# Paracetamol    11071
# Penicillin     11068
# Name: count, dtype: int64

# %%
#Disease distribution chart

disease_count.plot(kind='bar')

plt.title("Disease Distribution")
plt.xlabel("Medical Condition")
plt.ylabel("Number of patients")

plt.show()

# %%
#Disease distribution chart

disease_count.plot(kind='pie')

plt.title("Disease Distribution")
plt.xlabel("Medical Condition")
plt.ylabel("Number of patients")

plt.show()

# %%
#Disease distribution chart

disease_count.plot(kind='line')

plt.title("Disease Distribution")
plt.xlabel("Medical Condition")
plt.ylabel("Number of patients")

plt.show()

# %%
#  Age histogram

plt.hist(df['Age'])

plt.title("patient Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")

plt.show()

# %%
#KPI ANALYSIS

# %%
#Count hypertension patients

hypertension = df[df['Medical Condition'] == 'Hypertension']

rate = (len(hypertension) / len(df)) * 100

print("Hypertension Rate:", rate)
# Out:
# Hypertension Rate: 16.65765765765766

# %%
# Diabetes Prevalence

diabetes_yes = df[df['Medical Condition'] == 'Diabetes']

prevalence = (len(diabetes_yes) / len(df) )* 100

print("Diabetes prevalence:",prevalence)
# Out:
# Diabetes prevalence: 16.763963963963963

# %%
# AI & ML

# %%
# Machine learning / AI libraries

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# Convert Diabetes column

df['Diabetes_Risk'] = df['Diabetes_Risk'].map({'Yes':1, 'No':0})

# Features
x = df[['Age', 'BMI' ]]

# Target
y = df['Heart_Rate']

# %%
# Split training and testing

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
# Create model

model = LogisticRegression()

# Train model

model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
# Model Predictions

predictions = model.predict(x_test)

print(predictions)
# Out:
# [113 107  82 ...  87  85 107]

# %%
# Model accuracy

accuracy = accuracy_score(y_test, predictions)

print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.01783783783783784

# %%
import pickle

# save model

pickle.dump(model, open('Model/diabetes_model.pkl', 'wb'))

# %%
# Load model

loaded_model = pickle.load(open('Model/diabetes_model.pkl', 'rb'))

# %%
# Predict new patient

prediction = loaded_model.predict([[55,150]])

print(prediction)
# Out:
# [107]
# C:\Users\gasha\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
