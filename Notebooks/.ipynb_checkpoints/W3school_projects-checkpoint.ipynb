# %% [markdown]
# # W3school Python Projects

# %% [markdown]
# ## 1.Calculator

# %%
# Takes user input and converts input into decimal
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))


# Operators with error handling and debugging
print("\nChoose Operation")
print("1 = Addition")
print("2 = Subtraction")
print("3 = Multiplication")
print("4 = Division")
print("5 = Modulus")
print("6 = Power")



choice = input("Enter choice (1/2/3/4/5/6): ")


# Conditionals for decision making

if choice == "1":
    result = num1 + num2
    print("\nResult =",result)

elif choice == "2":
    result = num1 - num2
    print("\nResult = " ,result)

elif choice == "3":
    result = num1 * num2
    print("\nResult = ", result)

elif choice == "4":
   if num2 != 0:
       result = num1/num2
       print("\nResult =", result)

   else:
       print("\nError: Cannot divide by zero")

elif choice == "5":
    result = num1%num2
    print("\nResult = ", result)

elif choice == "6":
    result = num1**num2
    print("\nResult = " , result)

else:
    print("\nInvalid choice")
# Out:
# Enter first number:  3
# Enter second number:  4
# Choose Operation
# 1 = Addition
# 2 = Subtraction
# 3 = Multiplication
# 4 = Division
# 5 = Modulus
# 6 = Power
# Enter choice (1/2/3/4/5/6):  5
# Result =  3.0

# %% [markdown]
# ## 2.Even or Odd number Checker

# %%
number = int(input("Enter a number:"))

if number % 2 == 0:
    print("The Number is Even")
else:
    print("The Number is Odd")
# Out:
# Enter a number: 3
# The Number is Odd

# %%
number = int(input("Enter a number:"))

# Using f-Strings and Error handling using try-except 
try:
 if number % 2 == 0:
    print(f"\n{number} is Even")
 else:
    print(f"\n{number} is Odd")

except:

 print("\nInvalid input : Please enter numbers only.")
# Out:
# Enter a number: 3
# 3 is Odd

# %% [markdown]
# ### Positive or Negative Checker

# %%
number = int(input("Enter number"))
if number < 0:
    print("Negative")
elif number > 0:
     print("Positive")
elif number == 0:
      print("Zero")
# Out:
# Enter number 3
# Positive

# %%
ID = float(input("Enter Patient ID"))
Room = float(input("Enter Patient Room"))
Queue = int(input("Enter Patient Queue"))

if ID % 2 == 0:
  print("ID is Even")
else:
    print("ID is Odd")

if Room % 2 == 0:
  print("Room is Even")
else:
    print("Room is Odd")

if Queue % 2 == 0:
  print("Queue is Even")
else:
    print("Queue is Odd")
# Out:
# Enter Patient ID 3
# Enter Patient Room 4
# Enter Patient Queue 4
# ID is Odd
# Room is Even
# Queue is Even

# %% [markdown]
# ## 3.Lists

# %%
list = [1,4,9,16,25]
list
# Out:
# [1, 4, 9, 16, 25]

# %%
# indexing returns the item
list[0],list[-1],list[-3]
# Out:
# (1, 25, 9)

# %%
# Slicing returns a new list
list[-3:]
# Out:
# [9, 16, 25]

# %%
#Concatenation
list + [4,8,12,14,16]
# Out:
# [1, 4, 9, 16, 25, 4, 8, 12, 14, 16]

# %%
cubes = [1,8,27,65,125]
print(4**3)
# Out:
# 64

# %%
#Replace the wrong Value
cubes[3] = 64
cubes
# Out:
# [1, 8, 27, 64, 125]

# %%
#Add  values

cubes.append(216)
cubes.append(5**3)

print(cubes)
len(cubes)
# Out:
# [1, 8, 27, 64, 125, 216, 125]
# 7

# %%
cubes[2:5] = ['C', 'D', 'E']
cubes
# Out:
# [1, 8, 'C', 'D', 'E', 216, 125]

# %% [markdown]
# ## 4.Dictionary

# %%
tel = {'Sintayehu' : 4098, 'Muchie' : 4139}
tel['Wofe'] = 4123 
tel
# Out:
# {'Sintayehu': 4098, 'Muchie': 4139, 'Wofe': 4123}

# %%
# dict constructor : key-value pairs
dict ([('Samri', 4139), ('Efi', 4127), ('Jack',4098)])
# Out:
# {'Samri': 4139, 'Efi': 4127, 'Jack': 4098}

# %%
{x: x**2 for x in (2,4,6)}
# Out:
# {2: 4, 4: 16, 6: 36}

# %%
knights = {'Time': 'is Gold', 'Be': 'Brave'}

for k,v in knights.items():
    print(k,v)
# Out:
# Time is Gold
# Be Brave

# %%
for i,v in enumerate (['tic', 'tac', 'toe']):
    print(i,v)
# Out:
# 0 tic
# 1 tac
# 2 toe

# %%
questions = ['name', 'quest', 'favorite color']
answers = ['Lekasawa', 'Bekosa', 'Holy']

for q, a in zip(questions, answers):
    print('What is your {0}? It is {1}.'.format(q,a))
# Out:
# What is your name? It is Lekasawa.
# What is your quest? It is Bekosa.
# What is your favorite color? It is Holy.

# %% [markdown]
# ## 5.Password Generator

# %%
#Import random module

import random

letters = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ"

numbers = "0123456789"

symbols = "!@#$%^&*()?"

all_characters = letters + numbers + symbols

length = int(input("Enter password lenght:"))

password = ""


for i in range(length):
    random_character = random.choice(all_characters)

    password += random_character

print("\nGenerated Password:")
print(password)
# Out:
# Enter password lenght: 3
# Generated Password:
# jBL

# %%
#Professional password Generator



import random
import string


def generate_password(length):

    all_characters = (
        string.ascii_letters +
        string.digits +
        string.punctuation
    )


    password = ""

    for i in range(length):
        character = random.choice(all_characters)

        password += character

        return password


        
try:

    length = int(input("Enter password length:"))

    if length < 4:
        print("\nPassword should be at least 4 characters.")

    else:

        new_password = generate_password(length)

        print("\nGenerated password:")
        print(new_password)

except:
    print("\nInvalid input: please enter numbers only.")
# Out:
# Enter password length: 2
# Password should be at least 4 characters.

# %% [markdown]
# ## 6. QR Code Generator

# %%
pip install qrcode[pil]
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import qrcode

data = input("Enter text or URL:")

qr_image = qrcode.make(data)

qr_image.save("my_qrcode.png")

print("\nQR Code generated successfully")
print("Saved as my_qrcode.png")
# Out:
# Enter text or URL: Gash
# QR Code generated successfully
# Saved as my_qrcode.png

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import qrcode 
import os


output_folder = "GHC_QR_Codes"


if not os.path.exists(output_folder):
    os.makedirs(output_folder)

    

data = pd.read_excel("2018 GHC HPs Info.xlsx")

print("Excel file loaded successfully\n")



for index, row in data.iterrows():
 
    name = row["Fullname_Amharic"]
    eng_name = row["Fullname_English"]
    sex = row["Sex"]
    department = row["Department"]
    level = row["Level"]
    code = row["Code"]
    phone = row["Phone"]
    
    qr_text = (
    f"Fullname_Amharic:{name}\n"
    f"Fullname_English:{eng_name}\n"
    f"Sex:{sex}\n"
    f"Department:{department}\n"
    f"Level:{level}\n"
    f"Code:{code}\n"
    f"Phone:{phone}\n"
    )
    
    



    qr_image = qrcode.make(qr_text)

    filename = f"{eng_name}.png"


    filepath = os.path.join(output_folder,filename)

    qr_image.save(filepath)

    print(f"{filename} generated successfully")

    print ("\n All QR codes generated!")
# Out:
# Excel file loaded successfully
#
# Emebet legesse Woyeso.png generated successfully
#
#  All QR codes generated!
# Alemtila Alemu Wolde.png generated successfully
#
#  All QR codes generated!
# Mahlet Getachew Worku.png generated successfully
#
#  All QR codes generated!
# Foziya Ali Ahmed.png generated successfully
#
#  All QR codes generated!
# Derartu Chala Megersa.png generated successfully
#
#  All QR codes generated!
# Kamil Ahmed Abdillahi.png generated successfully
#
#  All QR codes generated!
# Tsegaye Abdela Ali.png generated successfully
#
#  All QR codes generated!
# Elias Mohammed Jabera.png generated successfully
#
#  All QR codes generated!
# Ayalnesh Chanie kebede.png generated successfully
#
#  All QR codes generated!
# Hana Demis Weldemeskel.png generated successfully
#
#  All QR codes generated!
# Zenaadis Wendimu Asres .png generated successfully
#
#  All QR codes generated!
# Hana Alemseged Gebremariam.png generated successfully
#
#  All QR codes generated!
# ...
